# %%
import mediapipe as mp
import cv2

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.pose_landmarks.landmark[0]
# Out:
# x: 0.46949863
# y: 0.24519028
# z: -1.012605
# visibility: 0.9998134

# %%
import csv
import os
import numpy as np

# %%
num_coords =  len(results.pose_landmarks.landmark)
num_coords
# Out:
# 33

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33']

# %%
with open('SOS.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "No SOS Alert"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
#             # Extract Face landmarks
#             face = results.face_landmarks.landmark
#             face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('SOS.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)  
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ea305b9c94a> in <module>
# ----> 1 cap = cv2.VideoCapture(0)
#       2 # Initiate holistic model
#       3 with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#       4
#       5     while cap.isOpened():
#
# NameError: name 'cv2' is not defined

# %%
results.pose_landmarks.landmark[0]
# Out:
# x: 0.51807564
# y: 0.26424146
# z: -0.84227836
# visibility: 0.9993577

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('SOS.csv')

# %%
df.head()
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 0  SOS Alert  0.595167  0.420220 -0.878537  0.999803  0.615782  0.346601
# 1  SOS Alert  0.597628  0.423514 -0.900585  0.999723  0.618563  0.351910
# 2  SOS Alert  0.592677  0.423725 -0.969094  0.999745  0.618090  0.350937
# 3  SOS Alert  0.596729  0.428677 -0.954908  0.999738  0.619089  0.355703
# 4  SOS Alert  0.599018  0.429019 -0.939752  0.999742  0.619419  0.357748
#
#          z2        v2        x3  ...       z31       v31       x32       y32  \
# 0 -0.859597  0.999675  0.626952  ...  0.814379  0.046095  0.533692  0.913801
# 1 -0.880614  0.999560  0.632228  ...  0.954578  0.042099  0.569402  0.761530
# 2 -0.956701  0.999598  0.630934  ...  0.955621  0.039387  0.575190  0.654574
# 3 -0.939246  0.999574  0.632948  ...  0.794688  0.036490  0.587743  0.852188
# 4 -0.922360  0.999575  0.633252  ...  0.737693  0.035769  0.598042  0.960672
#
#         z32       v32       x33       y33       z33       v33
# 0  0.791164  0.047948  0.472973  0.938492  0.746711  0.055675
# 1  0.941838  0.044285  0.512832  0.795402  0.887864  0.050970
# 2  0.936893  0.041396  0.495681  0.656752  0.911539  0.047636
# 3  0.635566  0.039123  0.519333  0.907805  0.700483  0.043821
# 4  0.610225  0.037929  0.537477  1.004740  0.651920  0.041435
#
# [5 rows x 133 columns]

# %%
df.tail()
# Out:
#             class        x1        y1        z1        v1        x2        y2  \
# 560  No SOS Alert  0.610797  0.314931 -1.234884  0.999645  0.618996  0.252622
# 561  No SOS Alert  0.631369  0.315718 -1.079355  0.999675  0.639791  0.253282
# 562  No SOS Alert  0.644083  0.316582 -1.013586  0.999698  0.649674  0.255828
# 563  No SOS Alert  0.648175  0.317558 -0.954957  0.999709  0.651616  0.259118
# 564  No SOS Alert  0.648067  0.324791 -0.611982  0.999733  0.650525  0.268004
#
#            z2        v2        x3  ...       z31       v31       x32  \
#
# 544  1.890262 -0.342978  0.033585  0.413312  1.878450 -0.276380  0.036726
# 138  2.117111 -0.623079  0.000996  0.438411  2.143876 -0.067630  0.000609
# 366  1.479642  0.262462  0.059664  0.437209  1.488540  0.385461  0.061657
# 504  1.982017 -0.307682  0.001048  0.498752  1.973445 -0.365280  0.000753
# 545  1.870363 -0.328465  0.030854  0.427434  1.882995 -0.281520  0.033306
#
# [170 rows x 132 columns]

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert'], dtype='<U12')

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9882352941176471

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'SOS Alert', 'SOS Alert', 'No SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'SOS Alert', 'No SOS Alert', 'No SOS Alert', 'No SOS Alert',
#        'SOS Alert', 'SOS Alert', 'No SOS Alert', 'SOS Alert',
#        'No SOS Alert', 'No SOS Alert', 'No SOS Alert'], dtype=object)

# %%
y_test
# Out:
# 487    No SOS Alert
# 229       SOS Alert
# 202       SOS Alert
# 419    No SOS Alert
# 189       SOS Alert
#            ...
# 544    No SOS Alert
# 138       SOS Alert
# 366    No SOS Alert
# 504    No SOS Alert
# 545    No SOS Alert
# Name: class, Length: 170, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
#         # 1. Draw face landmarks
#         mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
#                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
#                                  )
        
#         # 2. Right hand
#         mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
#                                  )

#         # 3. Left Hand
#         mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
#                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
#                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
#                                  )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
#             # Extract Face landmarks
#             face = results.face_landmarks.landmark
#             face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.86 0.14]
# No SOS Alert [0.85 0.15]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.81 0.19]
# No SOS Alert [0.65 0.35]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.61 0.39]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.89 0.11]
# No SOS Alert [0.89 0.11]
# No SOS Alert [0.89 0.11]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# SOS Alert [0.32 0.68]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.32 0.68]
# SOS Alert [0.33 0.67]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.32 0.68]
# SOS Alert [0.48 0.52]
# No SOS Alert [0.75 0.25]
# No SOS Alert [0.52 0.48]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.6 0.4]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.76 0.24]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.57 0.43]
# No SOS Alert [0.57 0.43]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.99 0.01]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.81 0.19]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.53 0.47]
# SOS Alert [0.36 0.64]
# SOS Alert [0.28 0.72]
# SOS Alert [0.25 0.75]
# SOS Alert [0.25 0.75]
# SOS Alert [0.26 0.74]
# SOS Alert [0.25 0.75]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.25 0.75]
# SOS Alert [0.25 0.75]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.25 0.75]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.26 0.74]
# SOS Alert [0.27 0.73]
# SOS Alert [0.35 0.65]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.26 0.74]
# SOS Alert [0.23 0.77]
# SOS Alert [0.23 0.77]
# SOS Alert [0.21 0.79]
# SOS Alert [0.21 0.79]
# SOS Alert [0.2 0.8]
# SOS Alert [0.21 0.79]
# SOS Alert [0.2 0.8]
# SOS Alert [0.2 0.8]
# SOS Alert [0.2 0.8]
# SOS Alert [0.2 0.8]
# SOS Alert [0.2 0.8]
# SOS Alert [0.2 0.8]
# SOS Alert [0.19 0.81]
# SOS Alert [0.18 0.82]
# SOS Alert [0.18 0.82]
# SOS Alert [0.19 0.81]
# SOS Alert [0.2 0.8]
# SOS Alert [0.19 0.81]
# SOS Alert [0.38 0.62]
# No SOS Alert [0.86 0.14]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# No SOS Alert [0.98 0.02]
# SOS Alert [0.41 0.59]
# SOS Alert [0.35 0.65]
# SOS Alert [0.34 0.66]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.32 0.68]
# SOS Alert [0.33 0.67]
# SOS Alert [0.35 0.65]
# SOS Alert [0.35 0.65]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.77 0.23]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.92 0.08]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.87 0.13]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.92 0.08]
# No SOS Alert [0.92 0.08]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.77 0.23]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.65 0.35]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.78 0.22]
# No SOS Alert [0.87 0.13]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.95 0.05]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.96 0.04]
# No SOS Alert [0.97 0.03]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.94 0.06]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.89 0.11]
# No SOS Alert [0.86 0.14]
# No SOS Alert [0.78 0.22]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.54 0.46]
# No SOS Alert [0.53 0.47]
# No SOS Alert [0.8 0.2]
# No SOS Alert [0.81 0.19]
# No SOS Alert [0.75 0.25]
# No SOS Alert [0.74 0.26]
# No SOS Alert [0.73 0.27]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.73 0.27]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.74 0.26]
# No SOS Alert [0.74 0.26]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.56 0.44]
# SOS Alert [0.35 0.65]
# SOS Alert [0.3 0.7]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# No SOS Alert [0.52 0.48]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.53 0.47]
# SOS Alert [0.47 0.53]
# SOS Alert [0.46 0.54]
# SOS Alert [0.43 0.57]
# SOS Alert [0.4 0.6]
# SOS Alert [0.37 0.63]
# SOS Alert [0.37 0.63]
# SOS Alert [0.46 0.54]
# SOS Alert [0.47 0.53]
# SOS Alert [0.49 0.51]
# No SOS Alert [0.75 0.25]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.57 0.43]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.65 0.35]
# No SOS Alert [0.65 0.35]
# SOS Alert [0.4 0.6]
# SOS Alert [0.3 0.7]
# SOS Alert [0.29 0.71]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.3 0.7]
# SOS Alert [0.3 0.7]
# SOS Alert [0.31 0.69]
# SOS Alert [0.31 0.69]
# SOS Alert [0.3 0.7]
# SOS Alert [0.32 0.68]
# SOS Alert [0.31 0.69]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.31 0.69]
# SOS Alert [0.32 0.68]
# SOS Alert [0.37 0.63]
# SOS Alert [0.39 0.61]
# SOS Alert [0.4 0.6]
# SOS Alert [0.4 0.6]
# SOS Alert [0.43 0.57]
# No SOS Alert [0.86 0.14]
# No SOS Alert [0.76 0.24]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.73 0.27]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.58 0.42]
# SOS Alert [0.37 0.63]
# SOS Alert [0.37 0.63]
# SOS Alert [0.37 0.63]
# SOS Alert [0.38 0.62]
# SOS Alert [0.38 0.62]
# SOS Alert [0.38 0.62]
# SOS Alert [0.38 0.62]
# SOS Alert [0.39 0.61]
# SOS Alert [0.4 0.6]
# SOS Alert [0.41 0.59]
# SOS Alert [0.4 0.6]
# SOS Alert [0.38 0.62]
# SOS Alert [0.38 0.62]
# SOS Alert [0.38 0.62]
# SOS Alert [0.43 0.57]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.76 0.24]
# No SOS Alert [0.74 0.26]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.76 0.24]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.6 0.4]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.6 0.4]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.68 0.32]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.69 0.31]
# No SOS Alert [0.73 0.27]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.51 0.49]
# No SOS Alert [0.5 0.5]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.58 0.42]
# SOS Alert [0.44 0.56]
# SOS Alert [0.45 0.55]
# No SOS Alert [0.62 0.38]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.57 0.43]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.73 0.27]
# SOS Alert [0.4 0.6]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# No SOS Alert [0.5 0.5]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.55 0.45]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.62 0.38]
# No SOS Alert [0.65 0.35]
# No SOS Alert [0.65 0.35]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.53 0.47]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.74 0.26]
# No SOS Alert [0.75 0.25]
# No SOS Alert [0.84 0.16]
# No SOS Alert [0.78 0.22]
# SOS Alert [0.41 0.59]
# No SOS Alert [0.79 0.21]
# SOS Alert [0.31 0.69]
# SOS Alert [0.26 0.74]
# SOS Alert [0.34 0.66]
# SOS Alert [0.33 0.67]
# SOS Alert [0.35 0.65]
# SOS Alert [0.32 0.68]
# SOS Alert [0.32 0.68]
# SOS Alert [0.35 0.65]
# SOS Alert [0.35 0.65]
# SOS Alert [0.33 0.67]
# SOS Alert [0.35 0.65]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.33 0.67]
# SOS Alert [0.33 0.67]
# SOS Alert [0.32 0.68]
# SOS Alert [0.34 0.66]
# SOS Alert [0.34 0.66]
# SOS Alert [0.33 0.67]
# SOS Alert [0.32 0.68]
# SOS Alert [0.35 0.65]
# SOS Alert [0.36 0.64]
# SOS Alert [0.32 0.68]
# No SOS Alert [0.76 0.24]
# SOS Alert [0.48 0.52]
# No SOS Alert [0.78 0.22]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.84 0.16]
# No SOS Alert [0.8 0.2]
# No SOS Alert [0.83 0.17]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.86 0.14]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.89 0.11]
# No SOS Alert [0.79 0.21]
# No SOS Alert [0.82 0.18]
# No SOS Alert [0.75 0.25]
# No SOS Alert [0.85 0.15]
# No SOS Alert [0.8 0.2]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.6 0.4]
# No SOS Alert [0.5 0.5]
# SOS Alert [0.41 0.59]
# No SOS Alert [0.53 0.47]
# No SOS Alert [0.6 0.4]
# No SOS Alert [0.53 0.47]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.55 0.45]
# No SOS Alert [0.51 0.49]
# No SOS Alert [0.52 0.48]
# No SOS Alert [0.57 0.43]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.52 0.48]
# No SOS Alert [0.59 0.41]
# No SOS Alert [0.61 0.39]
# No SOS Alert [0.53 0.47]
# No SOS Alert [0.71 0.29]
# No SOS Alert [0.67 0.33]
# No SOS Alert [0.56 0.44]
# No SOS Alert [0.51 0.49]
# SOS Alert [0.37 0.63]
# SOS Alert [0.42 0.58]
# No SOS Alert [0.55 0.45]
# No SOS Alert [0.58 0.42]
# No SOS Alert [0.64 0.36]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.72 0.28]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.66 0.34]
# No SOS Alert [0.7 0.3]
# No SOS Alert [0.55 0.45]
# No SOS Alert [0.63 0.37]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.93 0.07]
# No SOS Alert [0.92 0.08]
# No SOS Alert [0.91 0.09]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.9 0.1]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.88 0.12]
# No SOS Alert [0.9 0.1]
